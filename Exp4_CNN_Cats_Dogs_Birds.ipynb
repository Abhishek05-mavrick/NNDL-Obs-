# %% [markdown]
# ## Code

# %%
# Experiment 4 – CNN: Cats, Dogs, Birds
# Abhishek V Ammanagi | 2023BCSE07AED500

import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, models, Model
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report

print("=" * 55)
print("  Abhishek V Ammanagi  |  2023BCSE07AED500")
print("  Experiment 4: CNN – Cats, Dogs, Birds")
print("=" * 55)

IMG_SIZE    = 64
NUM_CLASSES = 3
EPOCHS      = 15
CLASS_NAMES = ['Birds','Cats','Dogs']
np.random.seed(42)

# Synthetic data – replace with real image dataset
X_train = np.random.rand(300, IMG_SIZE, IMG_SIZE, 3).astype('float32')
y_train = np.repeat([0,1,2], 100)
X_val   = np.random.rand(60,  IMG_SIZE, IMG_SIZE, 3).astype('float32')
y_val   = np.repeat([0,1,2], 20)
y_tr_c  = tf.keras.utils.to_categorical(y_train, NUM_CLASSES)
y_va_c  = tf.keras.utils.to_categorical(y_val,   NUM_CLASSES)

model = models.Sequential([
    layers.Conv2D(32,(3,3),activation='relu',padding='same',
                  input_shape=(IMG_SIZE,IMG_SIZE,3)),
    layers.Conv2D(32,(3,3),activation='relu',padding='same'),
    layers.MaxPooling2D(2), layers.Dropout(0.25),
    layers.Conv2D(64,(3,3),activation='relu',padding='same'),
    layers.Conv2D(64,(3,3),activation='relu',padding='same'),
    layers.MaxPooling2D(2), layers.Dropout(0.25),
    layers.Conv2D(128,(3,3),activation='relu',padding='same'),
    layers.MaxPooling2D(2), layers.Dropout(0.4),
    layers.Flatten(),
    layers.Dense(256, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(NUM_CLASSES, activation='softmax')
])
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
model.summary()

history = model.fit(X_train, y_tr_c,
                    validation_data=(X_val, y_va_c),
                    epochs=EPOCHS, batch_size=32)

loss, acc = model.evaluate(X_val, y_va_c, verbose=0)
y_pred    = np.argmax(model.predict(X_val), axis=1)
print(f"\nValidation Accuracy : {acc:.4f}")
print(classification_report(y_val, y_pred, target_names=CLASS_NAMES))

fig, ax = plt.subplots(1,2,figsize=(12,4))
ax[0].plot(history.history['accuracy'],     label='Train')
ax[0].plot(history.history['val_accuracy'], label='Val')
ax[0].set_title('Accuracy'); ax[0].legend(); ax[0].grid(True)
ax[1].plot(history.history['loss'],     label='Train')
ax[1].plot(history.history['val_loss'], label='Val')
ax[1].set_title('Loss'); ax[1].legend(); ax[1].grid(True)
plt.suptitle("Abhishek V Ammanagi | 2023BCSE07AED500", fontsize=9)
plt.tight_layout(); plt.savefig('exp4_curves.png',dpi=300); plt.show()

# Feature maps – first conv layer
fm_model = Model(inputs=model.inputs, outputs=model.layers[0].output)
fmaps    = fm_model.predict(X_val[0:1])
fig, axes = plt.subplots(4,8,figsize=(16,8))
for i, ax2 in enumerate(axes.flat):
    if i < fmaps.shape[-1]:
        ax2.imshow(fmaps[0,:,:,i], cmap='viridis')
    ax2.axis('off')
plt.suptitle("First Conv Layer Feature Maps\nAbhishek V Ammanagi | 2023BCSE07AED500", fontsize=9)
plt.tight_layout(); plt.savefig('exp4_fmaps.png',dpi=300); plt.show()

cm   = confusion_matrix(y_val, y_pred)
disp = ConfusionMatrixDisplay(cm, display_labels=CLASS_NAMES)
disp.plot(cmap='Blues')
plt.title("Confusion Matrix – Cats/Dogs/Birds")
plt.savefig('exp4_cm.png',dpi=300); plt.show()
print("Abhishek V Ammanagi | 2023BCSE07AED500")
# Out:
# =======================================================
#   Abhishek V Ammanagi  |  2023BCSE07AED500
#   Experiment 4: CNN – Cats, Dogs, Birds
# =======================================================
# c:\Users\manju\anaconda\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 64, 64, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 64, 64, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 32, 32, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 32, 32, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 32, 32, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 32, 32, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 16, 16, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 8192)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │     2,097,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 3)              │           771 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,237,603 (8.54 MB)
#  Trainable params: 2,237,603 (8.54 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/15
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 277ms/step - accuracy: 0.3600 - loss: 1.1445 - val_accuracy: 0.3333 - val_loss: 1.1015
# Epoch 2/15
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 180ms/step - accuracy: 0.3267 - loss: 1.1029 - val_accuracy: 0.3333 - val_loss: 1.0986
# Epoch 3/15
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 182ms/step - accuracy: 0.3500 - loss: 1.0998 - val_accuracy: 0.3333 - val_loss: 1.0987
# Epoch 4/15
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 183ms/step - accuracy: 0.3067 - loss: 1.1016 - val_accuracy: 0.3333 - val_loss: 1.0986
# Epoch 5/15
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 182ms/step - accuracy: 0.2733 - loss: 1.0991 - val_accuracy: 0.3333 - val_loss: 1.0986
# Epoch 6/15
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 180ms/step - accuracy: 0.3200 - loss: 1.0989 - val_accuracy: 0.3333 - val_loss: 1.0986
# Epoch 7/15
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 176ms/step - accuracy: 0.2667 - loss: 1.0988 - val_accuracy: 0.3333 - val_loss: 1.0986
# Epoch 8/15
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 186ms/step - accuracy: 0.3433 - loss: 1.0986 - val_accuracy: 0.3333 - val_loss: 1.0986
# Epoch 9/15
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 184ms/step - accuracy: 0.3333 - loss: 1.0988 - val_accuracy: 0.3333 - val_loss: 1.0986
# Epoch 10/15
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 184ms/step - accuracy: 0.2900 - loss: 1.0990 - val_accuracy: 0.3333 - val_loss: 1.0986
# Epoch 11/15
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 183ms/step - accuracy: 0.3100 - loss: 1.0990 - val_accuracy: 0.3333 - val_loss: 1.0986
# Epoch 12/15
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 184ms/step - accuracy: 0.3000 - loss: 1.0987 - val_accuracy: 0.3833 - val_loss: 1.0986
# Epoch 13/15
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 179ms/step - accuracy: 0.2967 - loss: 1.0989 - val_accuracy: 0.3333 - val_loss: 1.0986
# Epoch 14/15
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 176ms/step - accuracy: 0.3167 - loss: 1.0989 - val_accuracy: 0.3333 - val_loss: 1.0986
# Epoch 15/15
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 185ms/step - accuracy: 0.3433 - loss: 1.0988 - val_accuracy: 0.3333 - val_loss: 1.0986
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 287ms/step
#
# Validation Accuracy : 0.3333
#               precision    recall  f1-score   support
#
#        Birds       0.33      1.00      0.50        20
#         Cats       0.00      0.00      0.00        20
#         Dogs       0.00      0.00      0.00        20
#
#     accuracy                           0.33        60
#    macro avg       0.11      0.33      0.17        60
# weighted avg       0.11      0.33      0.17        60
# c:\Users\manju\anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\manju\anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\manju\anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# Abhishek V Ammanagi | 2023BCSE07AED500

# %% [markdown]
# ## Result
# _Run the cell above and paste your observations here._
